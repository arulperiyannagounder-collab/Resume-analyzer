# %% [markdown]
# <a href="https://colab.research.google.com/github/arulperiyannagounder-collab/Resume-analyzer/blob/main/RAG_Resume_analyser_using_Fiass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install faiss-cpu sentence-transformers openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 29.1 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer
import faiss
import openai

# %%
openai.api_key=''

# %%
doc=[
  "ARUL  P B. .TECH. ARTIFICIAL INTELLIGENCE & DATA SCIENCE PROJECTS Course Recommendation Engine: Developed a smart recommendation system that acts as a personal learning advisor, matching users with optimal courses based on their skills, goals, and interaction history. Engineered a scalable architecture with a RESTful API layer. GitHub: https://github.com/arulperiyannagounder-collab/Course-Recommendation Vehicle Type Classification System: Built and trained a Convolutional Neural Network (CNN) to classify vehicle images into 5 distinct categories achieving ~85% validation accuracy. Designed an intelligent decision logic layer to evaluate prediction reliability. GitHub: https://github.com/arulperiyannagounder-collab/Vehicle-classifier TECHNICAL SKILLS ·Languages:    Python, Java, JS, SQL,HTML ·Concepts:      OOPS ,Data Structures, Machine learning,Computer Vision. ·Tools:     Postgres,Docker,Kafka,Roboflow, Snowflake EDUCATION CERTIFICATIONS AWS Educate Cloud Computing arulperiyannagounder@gmail.com github.com/arulperiyannagounder-collab www.linkedin.com/in/arul-p-9a5361331 +91 8508192244 ABOUT Motivated Engineering student with a strong focus on Artificial Intelligence, Data science, Machine Learning, and Deep Learning. Proven ability to build functional AI solutions and RESTful APIs to solve complex, real world problems. Karpagam College of Engineering ,Coimbatore B.Tech Artificial Intelligence & Data Science (2024-2028) CGPA: 8.2 Rasi Matric Higher Secondary school , Salem 95%   on  Higher Secondary-2024 Rasi Matric Higher Secondary school , Salem 88%  on SSLC-2022 Introduction to Gen AI Data Science and Analysis (HP life) AI Tool Workshop MEMBERSHIPS 2025-2026 IEEE Student Member from KCE SB in Asia-Pacific Region. IAENG Member",
  "JEEVANRAJ SS B.TECH ARTIFICIAL INTELLIGENCE AND DATA SCIENCE KARPAGAM COLLEGE OF ENGINEERING jeevanrajsekar.s@gmail.com |  | Leetcode | https://github.com/jeevanraj3139 9080283795 Namakkal jeevanraj.blogspot.com jeevanraj3139@gmail.com ABOUT ME I am currently pursuing a Bachelor’s degree in Artificial Intelligence and Data Science, with a keen interest in machine learning, statistical modeling, and optimization techniques. Through academic projects, I have worked on data preprocessing, model building, and performance evaluation using tools like Python, NumPy, Pandas, and Scikit-learn. EDUCATION KARPAGAM COLLEGE OF ENGINEERING B.tech ARTIFICIAL INTELLIGENCE & DATA SCIENCE   - 7.35 CGPA JEIVIKASS HIGHER SECONDARY SCHOOL HSC                                                                                  - 78% GREENPARK MATRIC HIGHER SECONDARY SCHOOL SSLC SKILL- 64.2% Python Java Postgres KEY PROJECTS Kafka Roboflow Docker-Desktop Virtual Reader – AI Text to Speech Assistant A simple application that converts digital text into natural-sounding speech to assist visually impaired users and multitasking learners. The system allows users to upload documents or paste text and choose voice speed and language preferences. Implemented text-to-speech conversion using Python libraries Added basic file upload and voice control features Smart Attendance System – Face Recognition Based Tracker A basic AI system that marks attendance automatically using face recognition through a webcam. The system stores student details and generates attendance reports. Used OpenCV for face detection and recognition Generated automated attendance reports using CSV storage StudyTime Predictor – Student Performance Analyzer A predictive model that estimates student performance based on study hours, attendance, and assignment completion. Used regression techniques to predict marks Visualized performance trends using Matplotlib",

  ]

# %%
model=SentenceTransformer('all-MiniLM-L6-V2')
doc_embedding= model.encode(doc).astype('float32')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# ...

# %%
doc_embedding.shape
# Out:
# (1, 384)

# %%
dimension=doc_embedding.shape[1]
index=faiss.IndexFlatL2(dimension)
index.add(doc_embedding)

# %%
query="Where did Arul studied 12 th?"
query_embedding=model.encode([query]).astype('float32')

# %%
top_k=3
distance,indices=index.search(query_embedding,top_k)
retrived_chunks=[doc[i] for i in indices[0]]
print('retrived chunks')
for chunk in retrived_chunks:
  print('--',chunk)
# Out:
# retrived chunks
# ...
